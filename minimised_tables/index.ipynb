# %%
# Function to format the data
def format_data(data):
    formatted_data = {
        "Industry": data.get("IndustryIndustry name"),
        "Net Profit Variance": data.get("VarianceFull Year Net Profit Variance"),
        "Latest Equity": data.get("EquityLatest Equity"),
        "Face Value": data.get("Face ValueLatest Face Value"),
        "Total Reserves": data.get("ReservesTotal Reserve"),
        "Full Year Dividend %": data.get("DividendFull Year Dividend %"),
        "Full Year Net Sales": data.get("Sales TurnoverFull Year Net Sales"),
        "Full Year Net Profit": data.get("Net ProfitFull Year Net Profit"),
        "Full Year Cash Per Share": data.get("Full Year CPSFull Year Cash Per Share"),
        "Full Year Earning Per Share": data.get("Earning Per ShareFull Year Earning Per Share"),
        "Latest Quarter Net Sales": data.get("Latest Quarter SalesLatest Quarter Net Sales"),
        "Book Value": data.get("Book ValueBook value"),
        "Return on Net Worth": data.get("NetworthFull Year Return on Networth"),
        "Price to Book Value": data.get("Price/Book ValuePrice to Book value"),
        "Yearly PE Ratio": data.get("Yearly PE ratioFull Year Price to Earning per share"),
        "Yearly PC Ratio": data.get("Yearly PC ratioFull Year Price to Cash Per Share"),
        "BSE Value (in lakhs)": data.get("Bse valueBSE Value in lakhs"),
        "NSE Value (in lakhs)": data.get("Nse valueNSE Value in lakhs"),
        "52 Week High": data.get("High52 week high"),
        "52 Week Low": data.get("Low52 week low"),
        "Current Market Price (NSE)": data.get("PriceNSE Current market price"),
        "Market Cap (BSE/NSE)": data.get("Market capBSE / NSE Market Cap"),
        "Latest Quarter Net Profit": data.get("Net profitLatest Quarter Net Profit"),
        "Latest Quarter Net Profit Variance": data.get("Net profit varianceLatest Quarter Net Profit variance"),
        "Trailing Twelve Month (TTM) Sales": data.get("TTM SalesTrailing Twelve 12 month Net Sales"),
        "TTM Operating Profit": data.get("TTM OPTrailing Twelve 12 month Operating Profit"),
        "TTM Operating Profit Margin": data.get("TTM OPMTrailing Twelve 12 month Operating Profit Margin"),
        "TTM Gross Profit": data.get("TTM GPTrailing Twelve 12 month Gross Profit"),
        "TTM Gross Profit Margin": data.get("TTM GPMTrailing Twelve 12 month Gross Profit Margin"),
        "TTM Net Profit": data.get("TTM NPTrailing Twelve 12 month Net Profit"),
        "TTM Net Profit Variance": data.get("TTM NPVTrailing Twelve 12 month Net Profit Variane"),
        "TTM Earnings Per Share": data.get("TTM EPSTrailing Twelve 12 month EPS"),
        "TTM Price to Earnings Ratio": data.get("TTM PETrailing Twelve 12 month PE"),
        "TTM Depreciation": data.get("TTM DepreciationTrailing Twelve 12 month Depreciation"),
        "Latest Price (BSE/NSE)": data.get("LTPLatest Price (BSE/NSE)"),
        "Latest Gross Block": data.get("Gross blockLatest Gross Block"),
        "Total Loans": data.get("LoansTotal loans"),
        "Latest Advances for Banks": data.get("AdvancesLatest Advances for Banks"),
        "Latest Assets": data.get("Net profit assetLatest Assets"),
        "Full Year Operating Profit Margin": data.get("Year OPMFull Year Operating Profit Margin"),
        "Full Year Gross Profit Margin": data.get("Year GPMFull Year Gross Profit Margin"),
        "Latest Quarter Operating Profit Margin": data.get("Quarter OPMLatest quater Operation Profit Margin"),
    }
    return formatted_data

# Read data from file
with open('SUNPHARMA.txt', 'r') as file:
    lines = file.readlines()

# Parse data
data = {}
for line in lines:
    if line.strip():  # Skip empty lines
        parts = line.strip().split(':')
        key = parts[0].strip()
        value = ':'.join(parts[1:]).strip()
        data[key] = value

# Format the data
formatted_data = format_data(data)

# Print the formatted data
for key, value in formatted_data.items():
    print(f"{key}: {value}")
